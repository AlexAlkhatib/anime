# %% [markdown]
# ### Étude particulière du dataset "users-score-2023.csv" :

# %%
import pandas as pd
import gc
from surprise import Dataset, Reader, accuracy, SVD, SVDpp
from surprise.model_selection import train_test_split, GridSearchCV
from surprise.prediction_algorithms.knns import KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline
from surprise.prediction_algorithms.slope_one import SlopeOne
from surprise.prediction_algorithms.co_clustering import CoClustering
from sklearn.neighbors import NearestNeighbors

# %%
# Charger le dataset
user_score = pd.read_csv("./users-score-2023.csv")

# %%
# Aperçu du dataset
print(user_score.head())
print(user_score.info())
# Out:
#    user_id Username  anime_id             Anime Title  rating
# 0        1    Xinil        21               One Piece       9
# 1        1    Xinil        48             .hack//Sign       7
# 2        1    Xinil       320                  A Kite       5
# 3        1    Xinil        49        Aa! Megami-sama!       8
# 4        1    Xinil       304  Aa! Megami-sama! Movie       8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24325191 entries, 0 to 24325190
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user_id      int64
#  1   Username     object
#  2   anime_id     int64
#  3   Anime Title  object
#  4   rating       int64
# dtypes: int64(3), object(2)
# memory usage: 927.9+ MB
# None

# %% [markdown]
# ### Restreindre le dataset

# %%
# Fixer les seuils
min_user_ratings = 50  # Par exemple, les utilisateurs doivent avoir au moins noté 50 animes
min_anime_ratings = 10_000  # Par exemple, les animes doivent avoir au moins 10 000 notes

# Compter le nombre de notes par utilisateur et par anime
user_rating_counts = user_score.groupby('user_id').size()
anime_rating_counts = user_score.groupby('anime_id').size()

# Filtrer les utilisateurs avec au moins 10 notes et les animes avec au moins 100,000 notes
filtered_users = user_rating_counts[user_rating_counts >= min_user_ratings].index
filtered_animes = anime_rating_counts[anime_rating_counts >= min_anime_ratings].index

# Restreindre le dataset aux utilisateurs et animes filtrés
filtered_scores = user_score[user_score['user_id'].isin(filtered_users) & user_score['anime_id'].isin(filtered_animes)]

# %%
user_rating_counts
# Out:
# user_id
# 1          262
# 4          284
# 9           65
# 20         105
# 23         282
#           ...
# 1291057    240
# 1291079     94
# 1291085     59
# 1291087    210
# 1291097      3
# Length: 270033, dtype: int64

# %%
filtered_users
# Out:
# Index([      1,       4,       9,      20,      23,      37,      47,      48,
#             53,      66,
#        ...
#        1291015, 1291017, 1291021, 1291029, 1291033, 1291049, 1291057, 1291079,
#        1291085, 1291087],
#       dtype='int64', name='user_id', length=117568)

# %%
filtered_scores
# Out:
#           user_id   Username  anime_id  \
# 0               1      Xinil        21
# 1               1      Xinil        48
# 6               1      Xinil        53
# 7               1      Xinil        47
# 8               1      Xinil       591
# ...           ...        ...       ...
# 24325178  1291087  Oblongata     14813
# 24325179  1291087  Oblongata      8861
# 24325183  1291087  Oblongata     10578
# 24325184  1291087  Oblongata     12549
# 24325187  1291087  Oblongata       174
#
#                                                 Anime Title  rating
# 0                                                 One Piece       9
# 1                                               .hack//Sign       7
# 6                                             Ai Yori Aoshi       7
# 7                                                     Akira       5
# 8                                            Amaenaide yo!!       6
# ...                                                     ...     ...
# 24325178  Yahari Ore no Seishun Love Comedy wa Machigatt...       8
# 24325179  Yosuga no Sora: In Solitude, Where We Are Leas...       3
# 24325183                                                 C³       6
# 24325184                      Dakara Boku wa, H ga Dekinai.       4
# 24325187                                       Tenjou Tenge       6
#
# [11219809 rows x 5 columns]

# %%
import gc

# Supprimer la variable
del user_score

# Forcer le garbage collector à libérer la mémoire
gc.collect()

# filtered_scores devient user_score on prend juste un échantillon des 1000 premiers animés
filtered_scores = filtered_scores.head(1000)

# %%
# Vérifier la taille du dataset après filtrage
print(f"Nombre d'utilisateurs filtrés : {len(filtered_users)}")
print(f"Nombre d'animes filtrés : {len(filtered_animes)}")
print(f"Nombre de notes après filtrage : {len(filtered_scores)}")
# Out:
# Nombre d'utilisateurs filtrés : 117568
# Nombre d'animes filtrés : 598
# Nombre de notes après filtrage : 1000

# %% [markdown]
# ### Collaborative Filtering

# %%
# Créer le dataset pour Surprise
reader = Reader(rating_scale=(1, 10))  # Assuming rating scale is from 1 to 10
data = Dataset.load_from_df(filtered_scores[['user_id', 'anime_id', 'rating']], reader)

# %%
data

# %%
train, test = train_test_split(data, test_size=0.2)

# %%
print(type(train))
print(type(test))
# Out:
# <class 'surprise.trainset.Trainset'>
# <class 'list'>

# %%
cpt=0
for r in train.all_ratings():
  print(r)
  cpt+=1
  if cpt > 20:
    break
# Out:
# (0, 0, 8.0)
# (0, 1, 7.0)
# (0, 10, 6.0)
# (0, 24, 6.0)
# (0, 31, 5.0)
# (0, 39, 7.0)
# (0, 41, 8.0)
# (0, 48, 8.0)
# (0, 50, 9.0)
# (0, 53, 7.0)
# (0, 59, 8.0)
# (0, 60, 8.0)
# (0, 63, 2.0)
# (0, 5, 7.0)
# (0, 64, 7.0)
# (0, 69, 6.0)
# (0, 29, 7.0)
# (0, 75, 9.0)
# (0, 79, 7.0)
# (0, 23, 7.0)
# (0, 94, 8.0)

# %% [markdown]
# ### Construction du jeu antitest

# %%
full_train = data.build_full_trainset()
antitest = full_train.build_anti_testset()

# %%
print(antitest)
# Out:
# [(1, 298, 7.541), (1, 5525, 7.541), (1, 6682, 7.541), (1, 11759, 7.541), (1, 101, 7.541), (1, 102, 7.541), (1, 22199, 7.541), (1, 4744, 7.541), (1, 25013, 7.541), (1, 22729, 7.541), (1, 27655, 7.541), (1, 6547, 7.541), (1, 9989, 7.541), (1, 11433, 7.541), (1, 11111, 7.541), (1, 24833, 7.541), (1, 21995, 7.541), (1, 9919, 7.541), (1, 12967, 7.541), (1, 477, 7.541), (1, 9736, 7.541), (1, 5342, 7.541), (1, 2251, 7.541), (1, 3901, 7.541), (1, 6347, 7.541), (1, 7674, 7.541), (1, 10030, 7.541), (1, 2986, 7.541), (1, 22789, 7.541), (1, 10396, 7.541), (1, 13535, 7.541), (1, 20787, 7.541), (1, 7059, 7.541), (1, 10490, 7.541), (1, 31043, 7.541), (1, 31964, 7.541), (1, 33486, 7.541), (1, 36456, 7.541), (1, 10719, 7.541), (1, 14967, 7.541), (1, 6772, 7.541), (1, 8514, 7.541), (1, 14345, 7.541), (1, 31478, 7.541), (1, 1536, 7.541), (1, 10163, 7.541), (1, 12293, 7.541), (1, 5356, 7.541), (1, 10578, 7.541), (1, 28999, 7.541), (1, 10800, 7.541), (1, 14397, 7.541), (1, 4186, 7.541), (1, 14741, 7.541), (1, 18671, 7.541), (1, 2167, 7.541), (1, 11703, 7.541), (1, 12549, 7.541), (1, 16592, 7.541), (1, 35849, 7.541), (1, 15583, 7.541), (1, 28223, 7.541), (1, 8086, 7.541), (1, 9330, 7.541), (1, 28121, 7.541), (1, 2924, 7.541), (1, 1250, 7.541), (1, 2759, 7.541), (1, 3784, 7.541), (1, 3785, 7.541), (1, 8536, 7.541), (1, 18507, 7.541), (1, 9367, 7.541), (1, 5114, 7.541), (1, 908, 7.541), (1, 430, 7.541), (1, 123, 7.541), (1, 4725, 7.541), (1, 25183, 7.541), (1, 17895, 7.541), (1, 8425, 7.541), (1, 10793, 7.541), (1, 134, 7.541), (1, 13161, 7.541), (1, 31859, 7.541), (1, 20583, 7.541), (1, 32935, 7.541), (1, 28891, 7.541), (1, 587, 7.541), (1, 15225, 7.541), (1, 8630, 7.541), (1, 8074, 7.541), (1, 9515, 7.541), (1, 934, 7.541), (1, 1889, 7.541), (1, 9041, 7.541), (1, 3731, 7.541), (1, 228, 7.541), (1, 3092, 7.541), (1, 4814, 7.541), (1, 14467, 7.541), (1, 5680, 7.541), (1, 6862, 7.541), (1, 7054, 7.541), (1, 813, 7.541), (1, 467, 7.541), (1, 379, 7.541), (1, 790, 7.541), (1, 10087, 7.541), (1, 11741, 7.541), (1, 395, 7.541), (1, 578, 7.541), (1, 14719, 7.541), (1, 4282, 7.541), (1, 572, 7.541), (1, 34599, 7.541), (1, 512, 7.541), (1, 3655, 7.541), (1, 4437, 7.541), (1, 594, 7.541), (1, 4477, 7.541), (1, 29803, 7.541), (1, 528, 7.541), (1, 166, 7.541), (1, 9253, 7.541), (1, 16524, 7.541), (1, 11757, 7.541), (1, 6702, 7.541), (1, 1482, 7.541), (1, 28171, 7.541), (1, 1292, 7.541), (1, 7647, 7.541), (1, 9513, 7.541), (1, 1498, 7.541), (1, 4901, 7.541), (1, 11285, 7.541), (1, 1686, 7.541), (1, 2889, 7.541), (1, 762, 7.541), (1, 834, 7.541), (1, 11633, 7.541), (1, 405, 7.541), (1, 11241, 7.541), (1, 4981, 7.541), (1, 8915, 7.541), (1, 4182, 7.541), (1, 7338, 7.541), (1, 6573, 7.541), (1, 6880, 7.541), (1, 10155, 7.541), (1, 223, 7.541), (1, 225, 7.541), (1, 6033, 7.541), (1, 22297, 7.541), (1, 28701, 7.541), (1, 4192, 7.541), (1, 11617, 7.541), (1, 8277, 7.541), (1, 7088, 7.541), (1, 468, 7.541), (1, 18679, 7.541), (1, 22535, 7.541), (1, 801, 7.541), (1, 237, 7.541), (1, 4898, 7.541), (1, 6707, 7.541), (1, 18153, 7.541), (1, 17265, 7.541), (1, 23321, 7.541), (1, 18115, 7.541), (1, 14513, 7.541), (1, 20785, 7.541), (1, 23755, 7.541), (1, 442, 7.541), (1, 19815, 7.541), (1, 20507, 7.541), (1, 13601, 7.541), (1, 23281, 7.541), (1, 2993, 7.541), (1, 4214, 7.541), (1, 64, 7.541), (1, 4063, 7.541), (1, 5355, 7.541), (1, 154, 7.541), (1, 3588, 7.541), (1, 2418, 7.541), (1, 21881, 7.541), (1, 9941, 7.541), (1, 6213, 7.541), (1, 4654, 7.541), (1, 8937, 7.541), (1, 22319, 7.541), (1, 27899, 7.541), (1, 3167, 7.541), (1, 2787, 7.541), (1, 530, 7.541), (1, 740, 7.541), (1, 14713, 7.541), (1, 3503, 7.541), (1, 6045, 7.541), (1, 9656, 7.541), (1, 355, 7.541), (1, 4722, 7.541), (1, 534, 7.541), (1, 3470, 7.541), (1, 513, 7.541), (1, 14227, 7.541), (1, 3457, 7.541), (1, 4752, 7.541), (1, 4181, 7.541), (1, 10620, 7.541), (1, 2923, 7.541), (1, 713, 7.541), (1, 357, 7.541), (1, 6351, 7.541), (1, 4059, 7.541), (1, 376, 7.541), (1, 3958, 7.541), (1, 1004, 7.541), (1, 1887, 7.541 ...

# %% [markdown]
# ### Implémentation des métriques

# %% [markdown]
# ### Top N

# %%
def top_n(predictions, N, rating_min):
  df = pd.DataFrame(predictions)
  df = df[df["est"] >= rating_min].drop(["r_ui", "details"], axis=1)
  df = df.sort_values(by="est", ascending=False)
  df = df.groupby("uid").head(N)
  df = df.groupby("uid").agg({"iid": list, "est": list})
  df.columns = ["topn", "est"]
  return df

# %%
# topn = top_n(predictions, N=100, rating_min=0)

# %% [markdown]
# ### Cumulative Hit Rate
# ### Le hit rate correspond au cumulative hit rate avec un rating_min=0.

# %%
def count_hit(row):
  if isinstance(row["topn"], list):
    return 1 if row["iid"] in row["topn"] else 0
  else:
    return 0

def cumulative_hit_rate(topn, test):
  df_test = pd.DataFrame(test, columns = ["uid", "iid", "r_ui"])
  df_test =  df_test.set_index("uid")
  df_test["topn"] = topn["topn"]


  # Calcul du nombre de hits:
  hits = df_test.apply(count_hit, axis=1).sum()
  res = hits/len(test)

  return res

# %%
# cumulative_hit_rate(topn, test)

# %% [markdown]
# ### Average Reciprocal Hit Rate

# %%
def get_weight(row):
  """
  Si iid est dans le top N, on renvoie 1/p où p est la position de iid dans le top N
  Sinon, on renvoie 0
  """
  if isinstance(row["topn"], list):
    if row["iid"] in row["topn"]:
      return 1/(row["topn"].index(row["iid"]) + 1)
    else:
      return 0
  else:
    return 0

def average_reciprocal_hit_rate(topn, test):
  df_test = pd.DataFrame(test, columns = ["uid", "iid", "r_ui"])
  df_test =  df_test.set_index("uid")
  df_test["topn"] = topn["topn"]
  weights = df_test.apply(get_weight, axis=1).sum()
  res = weights/len(test)

  return res

# %%
# average_reciprocal_hit_rate(topn, test)

# %% [markdown]
# ### User Coverage

# %%
def check_threshold(row, threshold):
  """
  Retourne 1 s'il existe une note estimée au dessus du seuil, 0 sinon
  """
  if isinstance(row["est"], list):
    return 1 if row["est"][0] >= threshold else 0

  else:
    return 0

def user_coverage(topn, threshold=0):
  coverage = topn.apply(check_threshold, threshold=threshold, axis=1).sum()
  res = coverage/len(test)

  return res

# %%
# user_coverage(topn, threshold=5)

# %% [markdown]
# ### Création d'une fonction d'évaluation des modèles

# %%
import json
performances = {}

def evaluate_model(model, name, test, antitest=None, N=10, rating_min=0, threshold=0):
  predictions = model.test(test)
  mae = accuracy.mae(predictions, verbose=False)
  rmse = accuracy.rmse(predictions, verbose=False)
  performances[name] = {"MAE": mae, "RMSE": rmse}

  if antitest is not None:
    predictions = model.test(antitest)
    topn = top_n(N=N, predictions=predictions, rating_min=rating_min)
    chr = cumulative_hit_rate(topn=topn, test=test)
    arhr = average_reciprocal_hit_rate(topn=topn, test=test)
    uc = user_coverage(topn, threshold=threshold)

    performances[name]["Cumulative Hit Rate"] = chr
    performances[name]["Average Reciprocal Hit Rate"] = arhr
    performances[name]["User Coverage"] = uc

  print(json.dumps(performances, indent=2))

# %%
# evaluate_model(model=random_model, name="Modele gaussien", test=test, antitest=antitest, threshold=4, N=50, rating_min=2.5)

# %% [markdown]
# ### Collaborative Filtering

# %% [markdown]
# ### KNN basique (KNNBasic)

# %%
hyperparameters_knn_basic = {
    "k" : [20, 30, 40],
    "min_k" : [1, 3, 5],
    "sim_options": {
        "name": ["cosine", "msd", "pearson"],
        "user_based": [True]
    }
}

# %%
gs_knn_basic = GridSearchCV(
  KNNBasic,
  param_grid=hyperparameters_knn_basic,
  cv = 2,
  measures=['mae'],
)

# %%
gs_knn_basic.fit(data)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
best_knn_basic = gs_knn_basic.best_estimator["mae"]
print(best_knn_basic)
# Out:
# <surprise.prediction_algorithms.knns.KNNBasic object at 0x000001D82A344200>

# %%
best_knn_basic.fit(train)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
best_knn_basic.test(test)
# Out:
# [Prediction(uid=23, iid=13161, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=97, r_ui=9.0, est=8.00547761883207, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=4, iid=123, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=1, iid=12355, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=47, iid=4654, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=2904, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=263, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=1535, r_ui=7.0, est=8.002006622039215, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=47, iid=66, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=4725, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=120, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=8937, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=4, iid=11433, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=1, iid=7, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=240, r_ui=9.0, est=7.685871796495967, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=23, iid=4192, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=857, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=37, iid=60, r_ui=10.0, est=8.0, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=4, iid=2167, r_ui=10.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=2605, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=4, iid=15583, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=66, iid=1698, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=64, r_ui=6.0, est=7.011908271121798, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=1, iid=317, r_ui=7.0, est=8.24628899521895, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=47, iid=245, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=9, iid=93, r_ui=10.0, est=7.359435836627821, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=20, iid=512, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=13161, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=205, r_ui=8.0, est=8.337354527560068, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid=1, iid=392, r_ui=8.0, est=6.649200580264849, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=1, iid=1210, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=4, iid=4814, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=157, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=857, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=17265, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=47, iid=190, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=2986, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=317, r_ui=8.0, est=8.236608983808132, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=48, iid=9062, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=1210, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=1, iid=33, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=12549, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=9367, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=10490, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=853, r_ui=8.0, est=7.666680957082636, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=4, iid=6772, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=5205, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=20, iid=594, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=66, iid=101, r_ui=10.0, est=8.676049812202265, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=1, iid=245, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=433, r_ui=9.0, est=8.338579585213871, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=47, iid=121, r_ui=10.0, est=9.001836315779556, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=20, iid=9253, r_ui=10.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=1, iid=1519, r_ui=7.0, est=9.000000000000002, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=47, iid=587, r_ui=8.0, est=6.338329699327272, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=4, iid=908, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=9, iid=379, r_ui=1.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=1535, r_ui=8.0, est=8.001455074950647, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=47, iid=4382, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=245, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=30276, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=317, r_ui=7.0, est=8.248919427093801, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=23, iid=18153, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=166, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=37, iid=195, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=2904, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=27, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=121, r_ui=9.0, est=9.016150485380466, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=48, iid=450, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=20, iid=1698, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=2508, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=846, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=2593, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=37, iid=1698, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=18507, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=121, r_ui=9.0, est=9.005222540805791, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=66, iid=134, r_ui=8.0, est=6.994881411356107, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=47, iid=710, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=10800, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=4, iid=298, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=9, iid=174, r_ui=8.0, est=6.330904597125643, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=4, iid=14741, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=20, iid=430, r_ui=9.0, est=7.504690563124911, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid=23, iid=43, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=2167, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=3958, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=801, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=164, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=530, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=93, r_ui=8.0, est=7.329542868137943, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=48, iid=834, r_ui=4.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=5355, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=9041, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=2025, r_ui=6.0, est=8.248414105529667, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=23, iid=270, r_ui=10.0, est=7.975084606793245, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=4, iid=8074, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=11633, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=53, iid=256, r_ui=10.0, est=8.316148549539495, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=1, iid=1604, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=4654, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=237, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=137, r_ui=9.0, est=8.676896461822656, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=20, iid=457, r_ui=10.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=32, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=2963, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=405, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=31043, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=5355, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=47, iid=1117, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=37, iid=534, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=1222, r_ui=7.0, est=8.346685780398936, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=4, iid=3901, r_ui=10.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=9756, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=4, iid=6547, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=30, r_ui=6.0, est=7.016955482124022, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=23, iid=5525, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=6351, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=5342, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=66, iid=846, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=226, r_ui=9.0, est=8.11057652914791, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid=20, iid=11061, r_ui=10.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=9330, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=10067, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=53, iid=330, r_ui=10.0, est=7.669833171811461, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=66, iid=1575, r_ui=9.0, est=7.8017781440623, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=48, iid=5300, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=467, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=30, r_ui=1.0, est=7.073013961188089, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=4, iid=1575, r_ui=8.0, est=7.80027692798712, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=48, iid=7, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=9, iid=59, r_ui=8.0, est=7.80248729095343, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=23, iid=7088, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=71, r_ui=7.0, est=8.145536732301093, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid=48, iid=123, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=20, iid=1535, r_ui=9.0, est=7.998581071279167, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=37, iid=2787, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=527, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=66, iid=122, r_ui=9.0, est=7.012348297208071, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=48, iid=5081, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=1, iid=248, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=3002, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=3092, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=1530, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=1689, r_ui=8.0, est=9.003760922771484, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=4, iid=150, r_ui=9.0, est=8.204783077907718, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=9, iid=101, r_ui=9.0, est=8.678313112357545, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=53, iid=2986, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=5630, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=66, iid=1818, r_ui=8.0, est=7.798908641416818, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=48, iid=387, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=6, r_ui=8.0, est=8.680877140088546, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=4, iid=1536, r_ui=4.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=486, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=4654, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=597, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=2605, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=936, r_ui=4.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=585, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=14345, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=395, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=3230, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=4, iid=20787, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=166, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=101, r_ui=8.0, est=8.668060383760796, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=1, iid=147, r_ui=7.0, est=8.503862162941145, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=23, iid=5, r_ui=8.0, est=7.806632068102641, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=23, iid=9041, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=23, iid=9941, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=27899, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=37, iid=3457, r_ui=10.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=20507, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=339, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=3783, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=37, iid=182, r_ui=10.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=408, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=452, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=2167, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=357, r_ui=5.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=10030, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=37, iid=330, r_ui=8.0, est=7.66774086631341, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=53, iid=72, r_ui=10.0, est=8.67448011751532, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid=20, iid=164, r_ui=10.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=47, iid=232, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=5681, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=48, iid=164, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=1, iid=1571, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=48, iid=4182, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=11741, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=190, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=4, iid=10396, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=11617, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=23, iid=20787, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=4, iid=317, r_ui=4.0, est=8.24514882902414, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid=48, iid=6956, r_ui=7.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=37, iid=853, r_ui=9.0, est=7.6624551096752676, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=66, iid=48, r_ui=8.0, est=6.668312818438477, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=47, iid=401, r_ui=9.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid=20, iid=240, r_ui=7.0, est=7.675434456802269, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=47, iid=10620, r_ui=6.0, est=7.55375, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=1, iid=523, r_ui=8.0, est=7.55375, details={'was_impossible': True, 'reason': 'Not enough neighbors.'})]

# %%
# On observe beaucoup de "was impossible = True" le modèle n'arrive pas à faire des prédictions
trainset = best_knn_basic.trainset
antitest = trainset.build_anti_testset()

# %%
evaluate_model(model=best_knn_basic, name="KNN Basic", test=test, antitest=antitest,threshold=4, N=50, rating_min=5)
# Out:
# {
#   "KNN Basic": {
#     "MAE": 1.2590639819050304,
#     "RMSE": 1.5634364772503673,
#     "Cumulative Hit Rate": 0.24,
#     "Average Reciprocal Hit Rate": 0.018800024264368897,
#     "User Coverage": 0.05
#   }
# }

# %% [markdown]
# ### KNN avec moyennes (KNNWithMeans)

# %%
hyperparameters_knn_means = {
    "k" : [20, 30, 40],
    "min_k" : [1, 3, 5],
    "sim_options": {
        "name": ["cosine", "msd", "pearson"],
        "user_based": [True]
    }
}

# %%
gs_knn_means = GridSearchCV(
  KNNWithMeans,
  param_grid=hyperparameters_knn_means,
  cv = 2,
  measures=['mae'],
)

# %%
gs_knn_means.fit(data)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
best_knn_means = gs_knn_means.best_estimator["mae"]

# %%
best_knn_means.fit(train)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
evaluate_model(model=best_knn_means, name="KNN avec moyennes", test=test, antitest=antitest,threshold=4, N=50, rating_min=5)
# Out:
# {
#   "KNN Basic": {
#     "MAE": 1.2590639819050304,
#     "RMSE": 1.5634364772503673,
#     "Cumulative Hit Rate": 0.24,
#     "Average Reciprocal Hit Rate": 0.018800024264368897,
#     "User Coverage": 0.05
#   },
#   "KNN avec moyennes": {
#     "MAE": 1.1631594102502676,
#     "RMSE": 1.485557703361385,
#     "Cumulative Hit Rate": 0.225,
#     "Average Reciprocal Hit Rate": 0.021470230784661065,
#     "User Coverage": 0.05
#   }
# }

# %% [markdown]
# ### KNN centré réduit (KNNWithZScore)

# %%
hyperparameters_knn_zscore = {
    "k" : [20, 30, 40],
    "min_k" : [1, 3, 5],
    "sim_options": {
        "name": ["cosine", "msd", "pearson"],
        "user_based": [True]
    }
}

# %%
gs_knn_zscore = GridSearchCV(
  KNNWithZScore,
  param_grid=hyperparameters_knn_zscore,
  cv = 2,
  measures=['mae'],
)

# %%
gs_knn_zscore.fit(data)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
best_knn_zscore = gs_knn_zscore.best_estimator["mae"]

# %%
best_knn_zscore.fit(train)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
evaluate_model(model=best_knn_zscore, name="KNN centré réduit", test=test, antitest=antitest, threshold=4, N=50, rating_min=5)
# Out:
# {
#   "KNN Basic": {
#     "MAE": 1.2590639819050304,
#     "RMSE": 1.5634364772503673,
#     "Cumulative Hit Rate": 0.24,
#     "Average Reciprocal Hit Rate": 0.018800024264368897,
#     "User Coverage": 0.05
#   },
#   "KNN avec moyennes": {
#     "MAE": 1.1631594102502676,
#     "RMSE": 1.485557703361385,
#     "Cumulative Hit Rate": 0.225,
#     "Average Reciprocal Hit Rate": 0.021470230784661065,
#     "User Coverage": 0.05
#   },
#   "KNN centr\u00e9 r\u00e9duit": {
#     "MAE": 1.1887512321191276,
#     "RMSE": 1.5267650726402253,
#     "Cumulative Hit Rate": 0.245,
#     "Average Reciprocal Hit Rate": 0.02455819388364281,
#     "User Coverage": 0.05
#   }
# }

# %% [markdown]
# ### KNN en tenant compte des biais $b_u$ et $b_i$ (KNNBaseline)

# %%
hyperparameters_knn_bu_bi = {
    "k" : [20, 30, 40],
    "min_k" : [1, 3, 5],
    "sim_options": {
        "name": ["cosine", "msd", "pearson"],
        "user_based": [True]
    },
    "bsl_options": {
        "method": ["sgd"],
        "learning_rate": [0.005, 0.01]
    }
}

# %%
gs_knn_bu_bi = GridSearchCV(
  KNNBaseline,
  param_grid=hyperparameters_knn_bu_bi,
  cv = 2,
  measures=['mae'],
)

# %%
gs_knn_bu_bi.fit(data)
# Out:
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Estimating biases using sgd...
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
best_knn_bu_bi = gs_knn_bu_bi.best_estimator["mae"]

# %%
best_knn_bu_bi.fit(train)
# Out:
# Estimating biases using sgd...
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
evaluate_model(model=best_knn_bu_bi, name="KNN avec les biais bu et bi", test=test, antitest=antitest, threshold=4, N=50, rating_min=5)
# Out:
# {
#   "KNN Basic": {
#     "MAE": 1.2590639819050304,
#     "RMSE": 1.5634364772503673,
#     "Cumulative Hit Rate": 0.24,
#     "Average Reciprocal Hit Rate": 0.018800024264368897,
#     "User Coverage": 0.05
#   },
#   "KNN avec moyennes": {
#     "MAE": 1.1631594102502676,
#     "RMSE": 1.485557703361385,
#     "Cumulative Hit Rate": 0.225,
#     "Average Reciprocal Hit Rate": 0.021470230784661065,
#     "User Coverage": 0.05
#   },
#   "KNN centr\u00e9 r\u00e9duit": {
#     "MAE": 1.1887512321191276,
#     "RMSE": 1.5267650726402253,
#     "Cumulative Hit Rate": 0.245,
#     "Average Reciprocal Hit Rate": 0.02455819388364281,
#     "User Coverage": 0.05
#   },
#   "KNN avec les biais bu et bi": {
#     "MAE": 1.082168948536124,
#     "RMSE": 1.4308496700781395,
#     "Cumulative Hit Rate": 0.225,
#     "Average Reciprocal Hit Rate": 0.032892209021112395,
#     "User Coverage": 0.05
#   }
# }

# %% [markdown]
# ##### 1. Factorisation de Matrice sans Feedbacks Implicites : SVD (Singular Value Decomposition)
# ##### La méthode SVD est l'une des plus populaires pour la factorisation de matrice. Elle ne tient pas compte des feedbacks implicites et se base uniquement sur les ratings explicites des utilisateurs.
#
# ##### Étape 1 : Définir un dictionnaire d’hyperparamètres pour SVD
# ##### Les hyperparamètres principaux pour SVD incluent :
#
# ##### n_factors : Le nombre de facteurs latents.
# ##### n_epochs : Le nombre d'itérations pour entraîner le modèle.
# ##### lr_all : Le taux d'apprentissage pour la descente de gradient.
# ##### reg_all : Le coefficient de régularisation.

# %%
param_grid = {
    'n_factors': [50, 100, 150],   # Nombre de facteurs latents
    'n_epochs': [20, 30, 40],      # Nombre d'itérations
    'lr_all': [0.002, 0.005],      # Taux d'apprentissage
    'reg_all': [0.02, 0.1]         # Régularisation
}

# %%
# Initialiser GridSearchCV pour le modèle SVD
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=5)

# Appliquer la validation croisée sur le dataset
gs.fit(data)

# Afficher les meilleurs hyperparamètres
print(gs.best_params['rmse'])
# Out:
# {'n_factors': 100, 'n_epochs': 40, 'lr_all': 0.005, 'reg_all': 0.02}

# %%
# Récupérer les meilleurs hyperparamètres
best_params = gs.best_params['rmse']

# Entraîner le modèle avec ces hyperparamètres
SVDModel = SVD(n_factors=best_params['n_factors'],
           n_epochs=best_params['n_epochs'],
           lr_all=best_params['lr_all'],
           reg_all=best_params['reg_all'])

# Entraîner le modèle sur le jeu d'entraînement
SVDModel.fit(train)

# Tester le modèle sur le jeu de test
predictions = SVDModel.test(test)

# évaluer le modèle (Calculer et afficher les métriques)
# Calculer les métriques
rmse = accuracy.rmse(predictions, verbose=True)
mae = accuracy.mae(predictions, verbose=True)
# Out:
# RMSE: 1.4727
# MAE:  1.1054

# %% [markdown]
# ##### 2. Factorisation de Matrice avec Feedbacks Implicites : SVD++
# ##### Le modèle SVD++ prend en compte à la fois les feedbacks explicites et implicites. Cela inclut des interactions comme des clics, des ajouts à une liste de souhaits, des vues de films, etc., en plus des évaluations explicites données par les utilisateurs.
# ##### Étape 1 : Définir un dictionnaire d’hyperparamètres pour SVD++
# ##### Les hyperparamètres de SVD++ sont similaires à ceux de SVD, avec des facteurs supplémentaires pour les feedbacks implicites :
# ##### Étape 2 : Validation croisée avec GridSearchCV pour SVD++
# ##### La validation croisée se fait de la même manière que pour SVD, mais avec le modèle SVD++ :
# ##### Étape 3 : Mesurer l'efficacité sur le jeu de test (MAE et RMSE)
# ##### Vous pouvez maintenant entraîner le modèle SVD++ avec les meilleurs hyperparamètres et mesurer son efficacité :

# %%
# Initialiser GridSearchCV pour le modèle SVD++
gs = GridSearchCV(SVDpp, param_grid, measures=['rmse', 'mae'], cv=5)

# Appliquer la validation croisée
gs.fit(data)

# Afficher les meilleurs hyperparamètres
print(gs.best_params['rmse'])
# Out:
# {'n_factors': 100, 'n_epochs': 30, 'lr_all': 0.005, 'reg_all': 0.1}

# %%
# Récupérer les meilleurs hyperparamètres
best_params = gs.best_params['rmse']

# Entraîner le modèle avec ces hyperparamètres
SVDPPModel = SVDpp(n_factors=best_params['n_factors'],
             n_epochs=best_params['n_epochs'],
             lr_all=best_params['lr_all'],
             reg_all=best_params['reg_all'])

# Entraîner et tester le modèle
SVDPPModel.fit(train)
predictions = SVDPPModel.test(test)

# Calculer les métriques
rmse = accuracy.rmse(predictions, verbose=True)
mae = accuracy.mae(predictions, verbose=True)
# Out:
# RMSE: 1.4436
# MAE:  1.0919

# %% [markdown]
# ### One Slope

# %%
# Créer et entraîner le modèle Slope One
SlopeOneModel = SlopeOne()
SlopeOneModel.fit(train)

# %%
# Faire des prédictions sur le jeu de test
predictions = SlopeOneModel.test(test)

# Calculer le MAE et le RMSE pour évaluer les performances du modèle
mae = accuracy.mae(predictions)
rmse = accuracy.rmse(predictions)
# Out:
# MAE:  1.2049
# RMSE: 1.5952

# %% [markdown]
# ### Co Clustering

# %%
# Définir un dictionnaire d'hyperparamètres à explorer
hyperparameters = {
    'n_cltr_u': [3, 5, 7],  # Nombre de clusters d'utilisateurs
    'n_cltr_i': [3, 5, 7],  # Nombre de clusters d'items
    'n_epochs': [10, 20, 30]  # Nombre d'itérations pour l'entraînement
}

# Appliquer GridSearchCV pour trouver les meilleurs hyperparamètres
gs = GridSearchCV(CoClustering, hyperparameters, measures=['rmse', 'mae'], cv=2)
gs.fit(data)

# Afficher les meilleurs hyperparamètres et les résultats associés
print("Meilleurs hyperparamètres:", gs.best_params['rmse'])
print("Meilleur score RMSE:", gs.best_score['rmse'])
# Out:
# Meilleurs hyperparamètres: {'n_cltr_u': 3, 'n_cltr_i': 7, 'n_epochs': 20}
# Meilleur score RMSE: 1.5988770383292428

# %%
# Entraîner le modèle avec les meilleurs hyperparamètres
best_algo = gs.best_estimator['rmse']
best_algo.fit(train)

# %%
# Faire des prédictions sur le jeu de test
predictions = best_algo.test(test)

# Mesurer le MAE et le RMSE
mae = accuracy.mae(predictions)
rmse = accuracy.rmse(predictions)
# Out:
# MAE:  1.2773
# RMSE: 1.6214

# %% [markdown]
# ### Implémenter une fonction prenant un identifiant utilisateur en entrée et qui retournera le topN pour cet utilisateur sous la forme "titre" - "note moyenne"  - "nombre de notes".

# %%
# 1. Calculer le nombre de notes par anime
nb_ratings_per_anime = filtered_scores.groupby(by="anime_id").size().rename("nb_ratings")

# 2. Joindre le nombre de notes au dataset principal
# En utilisant merge pour ajouter la colonne nb_ratings au dataset score_dataset
score_dataset_with_ratings = filtered_scores.merge(nb_ratings_per_anime, on="anime_id", how="left")

# Optionnel : Vérifier le résultat
print(score_dataset_with_ratings.head())
# Out:
#    user_id Username  anime_id     Anime Title  rating  nb_ratings
# 0        1    Xinil        21       One Piece       9           3
# 1        1    Xinil        48     .hack//Sign       7           4
# 2        1    Xinil        53   Ai Yori Aoshi       7           4
# 3        1    Xinil        47           Akira       5           2
# 4        1    Xinil       591  Amaenaide yo!!       6           2

# %%
# 1. Calculer la note moyenne par anime
average_ratings_per_anime = score_dataset_with_ratings.groupby(by="anime_id")["rating"].mean().rename("average_ratings")

# 2. Joindre la note moyenne au dataset principal
# En utilisant merge pour ajouter la colonne average_ratings au dataset score_dataset
score_dataset_with_avg_ratings = score_dataset_with_ratings.merge(average_ratings_per_anime, on="anime_id", how="left")

# Optionnel : Vérifier le résultat
print(score_dataset_with_avg_ratings.head())
# Out:
#    user_id Username  anime_id     Anime Title  rating  nb_ratings  \
# 0        1    Xinil        21       One Piece       9           3
# 1        1    Xinil        48     .hack//Sign       7           4
# 2        1    Xinil        53   Ai Yori Aoshi       7           4
# 3        1    Xinil        47           Akira       5           2
# 4        1    Xinil       591  Amaenaide yo!!       6           2
#
#    average_ratings
# 0         8.333333
# 1         7.000000
# 2         7.250000
# 3         7.500000
# 4         5.500000

# %%
dict_title_to_id = dict(zip(score_dataset_with_avg_ratings["Anime Title"], score_dataset_with_avg_ratings["anime_id"] ))
dict_id_to_title = {v : k for k, v in dict_title_to_id.items()}

# %%
# Créer le DataFrame df_0 avec les caractéristiques de chaque anime
df_0 = pd.DataFrame({
    'anime_id': nb_ratings_per_anime.index,  # Identifiant de l'anime
    'anime_title': nb_ratings_per_anime.index.map(dict_id_to_title),  # Titre de l'anime
    'average_ratings': average_ratings_per_anime,  # Note moyenne
    'nb_ratings': nb_ratings_per_anime  # Nombre de notes
})

# Supprimer les animes avec des valeurs manquantes (si nécessaire)
df_0 = df_0.dropna()

# Afficher les premières lignes de df_0 pour vérifier
print(df_0.head())
# Out:
#           anime_id                      anime_title  average_ratings  \
# anime_id
# 1                1                     Cowboy Bebop         8.833333
# 5                5  Cowboy Bebop: Tengoku no Tobira         7.833333
# 6                6                           Trigun         8.500000
# 7                7               Witch Hunter Robin         8.000000
# 15              15                     Eyeshield 21         7.000000
#
#           nb_ratings
# anime_id
# 1                  6
# 5                  6
# 6                  4
# 7                  3
# 15                 2

# %%
from sklearn.neighbors import NearestNeighbors

def recommander_animes_utilisateur(user_id, score_dataset, df_0, model, n_recommendations=10):
    # Filtrer le dataset pour obtenir les animes notés par l'utilisateur
    animes_utilisateur = score_dataset[score_dataset['user_id'] == user_id]
    
    # Si l'utilisateur n'a pas d'animes, retourner un message vide
    if animes_utilisateur.empty:
        print(f"Aucun anime trouvé pour l'utilisateur {user_id}")
        return []
    
    # Choisir un anime de l'utilisateur pour la recommandation (ici, le premier)
    anime_id = animes_utilisateur.iloc[0]['anime_id']
    
    # Extraire le vecteur des caractéristiques de l'anime choisi par l'utilisateur
    film_1_vector = df_0[df_0['anime_id'] == anime_id][['average_ratings', 'nb_ratings']]

    # Utiliser le modèle KNN pour trouver les voisins les plus proches (recommandations)
    distance, neig = model.kneighbors(film_1_vector.to_numpy(), n_neighbors=n_recommendations + 1)  # +1 pour ignorer l'anime lui-même
    
    print("Anime Name : ")
    print(df_0[df_0['anime_id'] == anime_id])

    # Créer une liste pour stocker les recommandations
    recommendations = []

    # Parcourir les voisins et extraire les titres d'animes recommandés
    for i in range(1, len(distance[0])):  # Commencer à 1 pour ignorer l'anime de départ
        titre = df_0.iloc[neig[0][i]]['anime_title']
        avg_rating = df_0.iloc[neig[0][i]]['average_ratings']
        nb_ratings = df_0.iloc[neig[0][i]]['nb_ratings']
        
        # Ajouter la recommandation à la liste
        recommendations.append((titre, avg_rating, nb_ratings))
        print(f"{titre} recommandé avec une note moyenne de {avg_rating:.2f} et {nb_ratings} notes.")

    return recommendations

# %%
# Sélectionner les colonnes de caractéristiques (note moyenne et nombre de notes)
features = df_0[['average_ratings', 'nb_ratings']]

# Créer et entraîner le modèle KNN
model_knn = NearestNeighbors(n_neighbors=11, algorithm='auto')
model_knn.fit(features)

# Exemple d'appel de la fonction de recommandation
topN_recommendations = recommander_animes_utilisateur(user_id=1, score_dataset=score_dataset_with_avg_ratings, df_0=df_0, model=model_knn, n_recommendations=10)
# Out:
# Anime Name :
#           anime_id anime_title  average_ratings  nb_ratings
# anime_id
# 21              21   One Piece         8.333333           3
# Koukaku Kidoutai: Stand Alone Complex recommandé avec une note moyenne de 8.33 et 3 notes.
# Sword Art Online recommandé avec une note moyenne de 8.33 et 3 notes.
# Hajime no Ippo: New Challenger recommandé avec une note moyenne de 8.33 et 3 notes.
# Mushishi recommandé avec une note moyenne de 8.33 et 3 notes.
# One Piece recommandé avec une note moyenne de 8.33 et 3 notes.
# One Punch Man recommandé avec une note moyenne de 8.33 et 3 notes.
# Tengen Toppa Gurren Lagann recommandé avec une note moyenne de 8.67 et 3 notes.
# Higurashi no Naku Koro ni recommandé avec une note moyenne de 8.67 et 3 notes.
# Shingetsutan Tsukihime recommandé avec une note moyenne de 8.67 et 3 notes.
# Fruits Basket recommandé avec une note moyenne de 8.67 et 3 notes.
# C:\Users\anasa\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
